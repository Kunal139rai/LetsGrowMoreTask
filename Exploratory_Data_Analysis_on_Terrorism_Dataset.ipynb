# %% [markdown]
# ## **Exploratory Data Analysis on Terrorism Dataset**

# %% [markdown]
# Exploratory Data Analysis (EDA) is an approach to analyse the data using visual techniques. It is used to discover trends, patterns, or to check assumptions with the help of statistical summaries and graphical representations. EDA on terrorism dataset is performed to determine the hot zone of terrorism and the relationship between different features is displayed.
#
# The global terrorism dataset is downloaded from [here](https://drive.google.com/file/d/1luTU7xBvI7QAGPbQMxEHcgKUi9d6UeP_/view)

# %% [markdown]
# # Importing the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib_inline
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Reading the dataset

# %%
T_df =pd.read_csv('/content/globalterrorismdb_0718dist.csv',encoding='latin-1')

# %%
T_df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
T_df.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %% [markdown]
# # To view the shape of the dataset

# %%
print("There are {} rows and {} columns in the dataset".format(T_df.shape[0],T_df.shape[1]))
# Out:
# There are 181691 rows and 135 columns in the dataset

# %%
T_df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %% [markdown]
# # Checking the uniqueness of the columns of the dataset

# %%
no_of_cols = T_df.columns.nunique()
print("There are total %d columns in the data"%no_of_cols)
# Out:
# There are total 135 columns in the data

# %% [markdown]
# # Renaming the columns that are needed for our analysis

# %%
T_df=T_df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','region_txt':'Region','provstate':'State',
                          'city':'City','attacktype1_txt':'Attack_type','targtype1_txt':'Target_type','targsubtype1_txt':'Target_subtype'
                          ,'gname':'Gang_name','weaptype1_txt':'Weapon_type'})

# %%
T_df.head()
# Out:
#         eventid  Year  Month  Day approxdate  extended resolution  country  \
# 0  197000000001  1970      7    2        NaN         0        NaN       58
# 1  197000000002  1970      0    0        NaN         0        NaN      130
# 2  197001000001  1970      1    0        NaN         0        NaN      160
# 3  197001000002  1970      1    0        NaN         0        NaN       78
# 4  197001000003  1970      1    0        NaN         0        NaN      101
#
#               Country  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# ...

# %% [markdown]
# # Selecting only those columns which are actually required

# %%
T_df = T_df[['Year','Month','Day','Country','Region','State','City','Attack_type','Target_type','Target_subtype','Gang_name','Weapon_type']]

# %%
T_df.head()
# Out:
#    Year  Month  Day             Country                       Region    State  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean      NaN
# 1  1970      0    0              Mexico                North America  Federal
# 2  1970      1    0         Philippines               Southeast Asia   Tarlac
# 3  1970      1    0              Greece               Western Europe   Attica
# 4  1970      1    0               Japan                    East Asia  Fukouka
#
#             City                     Attack_type                  Target_type  \
# 0  Santo Domingo                   Assassination  Private Citizens & Property
# 1    Mexico city     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2        Unknown                   Assassination          Journalists & Media
# 3         Athens               Bombing/Explosion      Government (Diplomatic)
# 4        Fukouka  Facility/Infrastructure Attack      Government (Diplomatic)
#
# ...

# %% [markdown]
# # Checking the updated shape of the dataset

# %%
T_df.shape
# Out:
# (181691, 12)

# %% [markdown]
# # Checking for the null values

# %%
T_df.isnull().sum()
# Out:
# Year                  0
# Month                 0
# Day                   0
# Country               0
# Region                0
# State               421
# City                434
# Attack_type           0
# Target_type           0
# Target_subtype    10373
# Gang_name             0
# Weapon_type           0
# dtype: int64

# %% [markdown]
# # Filling the NaN values

# %%
T_df['Target_subtype'] = T_df['Target_subtype'].fillna('others')

# %%
T_df['State']=T_df['State'].fillna('Unknown')

# %%
T_df.replace( {"Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)": "Vehicle"},inplace = True)

# %%
T_df
# Out:
#         Year  Month  Day             Country                       Region  \
# 0       1970      7    2  Dominican Republic  Central America & Caribbean
# 1       1970      0    0              Mexico                North America
# 2       1970      1    0         Philippines               Southeast Asia
# 3       1970      1    0              Greece               Western Europe
# 4       1970      1    0               Japan                    East Asia
# ...      ...    ...  ...                 ...                          ...
# 181686  2017     12   31             Somalia           Sub-Saharan Africa
# 181687  2017     12   31               Syria   Middle East & North Africa
# 181688  2017     12   31         Philippines               Southeast Asia
# 181689  2017     12   31               India                   South Asia
# 181690  2017     12   31         Philippines               Southeast Asia
#
#                   State           City                     Attack_type  \
# ...

# %%
T_df.shape
# Out:
# (181691, 12)

# %%
T_df.isnull().sum()
# Out:
# Year                0
# Month               0
# Day                 0
# Country             0
# Region              0
# State               0
# City              434
# Attack_type         0
# Target_type         0
# Target_subtype      0
# Gang_name           0
# Weapon_type         0
# dtype: int64

# %%
T_df.head(12)
# Out:
#     Year  Month  Day             Country                       Region  \
# 0   1970      7    2  Dominican Republic  Central America & Caribbean
# 1   1970      0    0              Mexico                North America
# 2   1970      1    0         Philippines               Southeast Asia
# 3   1970      1    0              Greece               Western Europe
# 4   1970      1    0               Japan                    East Asia
# 5   1970      1    1       United States                North America
# 6   1970      1    2             Uruguay                South America
# 7   1970      1    2       United States                North America
# 8   1970      1    2       United States                North America
# 9   1970      1    3       United States                North America
# 10  1970      1    1       United States                North America
# 11  1970      1    6       United States                North America
#
# ...

# %%
T_df.columns.unique()
# Out:
# Index(['Year', 'Month', 'Day', 'Country', 'Region', 'State', 'City',
#        'Attack_type', 'Target_type', 'Target_subtype', 'Gang_name',
#        'Weapon_type'],
#       dtype='object')

# %%
T_df.columns.nunique()
# Out:
# 12

# %%
Total_countries= T_df['Country'].nunique()
print("Total %d countries were noted in the data"%Total_countries)
# Out:
# Total 205 countries were noted in the data

# %%
Total_countries1= T_df['Country'].unique()
Total_countries1
# Out:
# array(['Dominican Republic', 'Mexico', 'Philippines', 'Greece', 'Japan',
#        'United States', 'Uruguay', 'Italy', 'East Germany (GDR)',
#        'Ethiopia', 'Guatemala', 'Venezuela', 'West Germany (FRG)',
#        'Switzerland', 'Jordan', 'Spain', 'Brazil', 'Egypt', 'Argentina',
#        'Lebanon', 'Ireland', 'Turkey', 'Paraguay', 'Iran',
#        'United Kingdom', 'Colombia', 'Bolivia', 'Nicaragua',
#        'Netherlands', 'Belgium', 'Canada', 'Australia', 'Pakistan',
#        'Zambia', 'Sweden', 'Costa Rica', 'South Yemen', 'Cambodia',
#        'Israel', 'Poland', 'Taiwan', 'Panama', 'Kuwait',
#        'West Bank and Gaza Strip', 'Austria', 'Czechoslovakia', 'India',
#        'France', 'South Vietnam', 'Brunei', 'Zaire',
#        "People's Republic of the Congo", 'Portugal', 'Algeria',
#        'El Salvador', 'Thailand', 'Haiti', 'Sudan', 'Morocco', 'Cyprus',
#        'Myanmar', 'Afghanistan', 'Peru', 'Chile', 'Honduras',
# ...

# %%
print(T_df['Region'].unique())
# Out:
# ['Central America & Caribbean' 'North America' 'Southeast Asia'
#  'Western Europe' 'East Asia' 'South America' 'Eastern Europe'
#  'Sub-Saharan Africa' 'Middle East & North Africa' 'Australasia & Oceania'
#  'South Asia' 'Central Asia']

# %%
print(T_df['Attack_type'].unique())
# Out:
# ['Assassination' 'Hostage Taking (Kidnapping)' 'Bombing/Explosion'
#  'Facility/Infrastructure Attack' 'Armed Assault' 'Hijacking' 'Unknown'
#  'Unarmed Assault' 'Hostage Taking (Barricade Incident)']

# %%
print(T_df['Target_type'].unique())
# Out:
# ['Private Citizens & Property' 'Government (Diplomatic)'
#  'Journalists & Media' 'Police' 'Utilities' 'Military'
#  'Government (General)' 'Airports & Aircraft' 'Business'
#  'Educational Institution' 'Violent Political Party'
#  'Religious Figures/Institutions' 'Unknown' 'Transportation' 'Tourists'
#  'NGO' 'Telecommunication' 'Food or Water Supply'
#  'Terrorists/Non-State Militia' 'Other' 'Maritime' 'Abortion Related']

# %%
print(T_df['Gang_name'].nunique())
# Out:
# 3537

# %%
print(T_df['Gang_name'].unique())
# Out:
# ['MANO-D' '23rd of September Communist League' 'Unknown' ...
#  'Fatoni Warriors' 'Minorities of Metropolitan Attacks'
#  'Baloch Republican Party']

# %%
print(T_df['Weapon_type'].unique())
# Out:
# ['Unknown' 'Explosives' 'Incendiary' 'Firearms' 'Chemical' 'Melee'
#  'Sabotage Equipment' 'Vehicle' 'Fake Weapons' 'Radiological' 'Other'
#  'Biological']

# %%
T_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Year            181691 non-null  int64
#  1   Month           181691 non-null  int64
#  2   Day             181691 non-null  int64
#  3   Country         181691 non-null  object
#  4   Region          181691 non-null  object
#  5   State           181691 non-null  object
#  6   City            181257 non-null  object
#  7   Attack_type     181691 non-null  object
#  8   Target_type     181691 non-null  object
#  9   Target_subtype  181691 non-null  object
#  10  Gang_name       181691 non-null  object
#  11  Weapon_type     181691 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 16.6+ MB

# %%
T_df.describe()
# Out:
#                 Year          Month            Day
# count  181691.000000  181691.000000  181691.000000
# mean     2002.638997       6.467277      15.505644
# std        13.259430       3.388303       8.814045
# min      1970.000000       0.000000       0.000000
# 25%      1991.000000       4.000000       8.000000
# 50%      2009.000000       6.000000      15.000000
# 75%      2014.000000       9.000000      23.000000
# max      2017.000000      12.000000      31.000000

# %%
T_df['Country'].value_counts().head(10)
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: Country, dtype: int64

# %%
T_df['Region'].value_counts().head(10)
# Out:
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Name: Region, dtype: int64

# %%
T_df['State'].value_counts().head(10)
# Out:
# Baghdad               7645
# Unknown               4711
# Northern Ireland      4498
# Balochistan           3710
# Saladin               3411
# Al Anbar              3299
# Nineveh               3241
# Sindh                 3206
# Khyber Pakhtunkhwa    3084
# Diyala                3041
# Name: State, dtype: int64

# %%
T_df['Target_subtype'].value_counts().head(10)
# Out:
# Unnamed Civilian/Unspecified                               11596
# Police Security Forces/Officers                            11178
# others                                                     10373
# Military Unit/Patrol/Convoy                                 8277
# Military Personnel (soldiers, troops, officers, forces)     7963
# Government Personnel (excluding police, military)           6610
# Village/City/Town/Suburb                                    6542
# Politician or Political Party Movement/Meeting/Rally        6306
# Police Building (headquarters, station, school)             5907
# Military Barracks/Base/Headquarters/Checkpost               5211
# Name: Target_subtype, dtype: int64

# %%
T_df['City'].value_counts().head(10)
# Out:
# Unknown         9775
# Baghdad         7589
# Karachi         2652
# Lima            2359
# Mosul           2265
# Belfast         2171
# Santiago        1621
# Mogadishu       1581
# San Salvador    1558
# Istanbul        1048
# Name: City, dtype: int64

# %%
T_df['Attack_type'].value_counts().head(10)
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: Attack_type, dtype: int64

# %%
T_df['Target_type'].value_counts().head(10)
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Name: Target_type, dtype: int64

# %%
T_df['Gang_name'].value_counts().head(10)
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Al-Shabaab                                           3288
# New People's Army (NPA)                              2772
# Irish Republican Army (IRA)                          2671
# Revolutionary Armed Forces of Colombia (FARC)        2487
# Boko Haram                                           2418
# Name: Gang_name, dtype: int64

# %%
T_df['Weapon_type'].value_counts().head(10)
# Out:
# Explosives            92426
# Firearms              58524
# Unknown               15157
# Incendiary            11135
# Melee                  3655
# Chemical                321
# Sabotage Equipment      141
# Vehicle                 136
# Other                   114
# Biological               35
# Name: Weapon_type, dtype: int64

# %% [markdown]
# # Visualizing the Dataset

# %% [markdown]
# # Attack by weapons type

# %%
plt.figure(figsize=(20,5));
plt.xticks(rotation = 50)
plt.title('Attack: Weapons Type', fontsize = 30)
sns.countplot(x=T_df.Weapon_type);

# %% [markdown]
# # Attacks by year

# %%
plt.figure(figsize=(20,5));
plt.xticks(rotation = 90)
plt.title('Attack:YEAR', fontsize = 25)
sns.countplot(x=T_df.Year);

# %% [markdown]
# # Attacks by month

# %%
plt.figure(figsize=(20,5));
plt.title('Attacks by Month',fontsize = 25)
sns.countplot(x=T_df.Month);

# %% [markdown]
# # Attack by Day

# %%
plt.figure(figsize=(20,5));
plt.title('Attack by Day',fontsize = 25)
sns.countplot(x=T_df.Day);

# %% [markdown]
# # Cities with most attacks

# %%
plt.subplots(figsize=(20, 10))
top_countries = T_df['Country'].value_counts()[:10]
sns.barplot(x=top_countries.index, y=top_countries.values, palette='hls')
plt.title('Top 10 most affected countries', fontsize=25)
plt.xlabel('Country')
plt.ylabel('Number of attacks')
plt.xticks(rotation=0)
plt.show()

# %%
plt.subplots(figsize=(20, 10))
top_states = T_df['State'].value_counts()[:10]
sns.barplot(x=top_states.index, y=top_states.values, palette='hls')
plt.title('Top 10 most affected states', fontsize=25)
plt.xlabel('State')
plt.ylabel('Number of attacks')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # Attacks by Region

# %%
plt.figure(figsize=(28,5));
plt.rcParams.update({'font.size': 15});
plt.xticks(rotation = 90)
plt.title('Attacks by Region',fontsize =25)
sns.countplot(x=T_df.Region);

# %% [markdown]
# # Attack based on Target type

# %%
plt.figure(figsize=(20,5));
plt.rcParams.update({'font.size':15});
plt.xticks(rotation = 90)
plt.title('Based on Target type', fontsize =25)
sns.countplot(x=T_df.Target_type);

# %% [markdown]
# # Attacks based on attack type

# %%
plt.figure(figsize=(25,5));
plt.rcParams.update({'font.size':15});
plt.xticks(rotation = 90)
plt.title('Based on Attack type', fontsize = 25)
sns.countplot(x=T_df.Attack_type);

# %% [markdown]
# ## **Result of the Analysis**

# %% [markdown]
# After observing different graphs, we obtained the following results:
#
# Explosive : Most used weapon type in attacks
#
# 2014 : Most number of attacks year
#
# 5th month(May) : Most number of attacks month
#
# 15th day of month : Most number of attacks day
#
# Iraq : Most attacked country
#
# Baghdad : Most attacked State
#
# Middle East and North America : Most attacked region
#
# Private Citizens and Property : Most attack based on target type
#
# Bombing /Explosion : Most attack based on attack type

# %% [markdown]
# # Security issues and insight from the EDA

# %% [markdown]
# From above result of analysis it is clear that explosive is the most used weapon type in the attacks. And keeping track of other result. Following measures can be adopted to reduce the number of attacks and terrorism.
#
# * The government should firmly tighten border security
#
# * Strict immigration laws and regulations should be put in place.
#
# * It is important to restrict access to lethal weapons.
#
# * States should ensure their internal security.
